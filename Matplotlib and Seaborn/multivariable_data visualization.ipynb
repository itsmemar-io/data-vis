# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import matplotlib.dates as mdates
import scipy.stats as stats
# %matplotlib inline
import seaborn as sns
import datetime

# %%
df = pd.read_csv('coches.csv')

# %%
df.fillna(method = 'ffill', inplace = True)
mpg = df['mpg']
weight = df['weight']
length = df['length']

# %%
ax = sns.jointplot(x = 'weight', y = 'length', data = df,
                 kind = 'reg', joint_kws = {'line_kws':{'color':'g'}})

# %%
ax = sns.jointplot(x = 'weight', y = 'length', data = df,
                 kind = 'kde', hue = 'foreign')

# %%
ax = sns.lmplot(x = 'weight', y = 'length', data = df, hue = 'foreign')
